# %% [markdown]
# # Домашнее задание 6: классификация текстов

# %% [markdown]
# В этом домашнем задании вам предстоит построить классификатор текстов!
#
# Данные мы будем использовать из Kaggle соревнования: https://www.kaggle.com/competitions/nlp-getting-started/data
#
#
# Оттуда надо скачать файл train.csv. На обучающую и тестовую выборки его поделим кодом ниже, менять его не надо!

# %% [markdown]
# Мы будем работать с датасетом постов из твиттера. Нам предстоит решать задачу бинарной классификации - определять содержатся ли в твитте информация о настоящей катастрофе/инциденте или нет.

# %%
import numpy as np
import pandas as pd
from typing import  List
import matplotlib.pyplot as plt
import seaborn as sns
from string import punctuation
import re
import nltk

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.3, random_state=42)

# %% [markdown]
# ## Задание 1 (0.5 балла)
#
# Выведете на экран информацию о пропусках в данных. Если пропуски присутствуют заполните их пустой строкой.

# %%
train.isnull().sum()
# Out:
# id             0
# keyword       44
# location    1760
# text           0
# target         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id            0
# keyword      17
# location    773
# text          0
# target        0
# dtype: int64

# %%
train['keyword'] = np.where(train['keyword'].isnull(), '', train['keyword'])
test['keyword'] = np.where(test['keyword'].isnull(), '', test['keyword'])
train['location'] = np.where(train['location'].isnull(), '', train['location'])
test['location'] = np.where(test['location'].isnull(), '', test['location'])
test
# Out:
#         id      keyword                      location  \
# 2644  3796  destruction
# 2227  3185       deluge
# 5448  7769       police                            UK
# 132    191   aftershock
# 6845  9810       trauma         Montgomery County, MD
# ...    ...          ...                           ...
# 4307  6115     hellfire  570 Vanderbilt; Brooklyn, NY
# 3375  4833   evacuation                           USA
# 1710  2466     collided
# 4898  6973     massacre                       Ireland
# 6753  9674      tornado                 Asheville, NC
#
#                                                    text  target
# 2644  So you have a new weapon that can cause un-ima...       1
# 2227  The f$&amp;@ing things I do for #GISHWHES Just...       0
# 5448  DT @georgegalloway: RT @Galloway4Mayor: ÛÏThe...       1
# 132   Aftershock back to school kick off was great. ...       0
# 6845  in response to trauma Children of Addicts deve...       0
# ...                                                 ...     ...
# 4307  New cocktail on the list! El Diablo Mas Verde:...       0
# 3375  Bend Post Office roofers cut gas line prompt e...       1
# 1710  Monsoon flooding - Monsoon rains have have hit...       1
# 4898  Remember this was a massacre of civilians. #Hi...       1
# 6753  I liked a @YouTube video http://t.co/itnKBxgWL...       1
#
# [2284 rows x 5 columns]

# %% [markdown]
# ## Задание 2 (1 балл)
# Давайте немного посмотрим на наши данные. Визуализируйте (где явно просят) или выведете информацию о следующем:
#
# 1. Какое распределение классов в обучающей выборке?

# %%
values = train['target'].value_counts()
values[1] / values[0]
# Out:
# 0.7622354497354498

# %% [markdown]
# 2. Посмотрите на колонку "keyword" - возьмите 10 наиболее встречающихся значений, постройте ступенчатую диаграмму распределения классов в зависимости от значения keyword, сделайте выводы.

# %%
popular_keywords = data['keyword'].value_counts().index[:10]
most_popular = data[data['keyword'].isin(popular_keywords)]
most_popular
# Out:
#         id     keyword                   location  \
# 304    446  armageddon  California, United States
# 305    447  armageddon  California, United States
# 306    448  armageddon           #FLIGHTCITY UK
# 307    450  armageddon                        NaN
# 308    451  armageddon                        NaN
# ...    ...         ...                        ...
# 6121  8737     sinking                     London
# 6122  8738     sinking           Rhyme Or Reason?
# 6123  8739     sinking                         MA
# 6124  8740     sinking                hey Georgia
# 6125  8741     sinking                   Coventry
#
#                                                    text  target
# 304   #PBBan (Temporary:300) avYsss @'aRmageddon | D...       0
# 305   #PBBan (Temporary:300) Russaky89 @'aRmageddon ...       0
# 306   ((OFFICIAL VID)) #DoubleCups &gt;&gt; https://...       0
# 307                 ouvindo Peace Love &amp; Armageddon       0
# 308   Best movie you've ever seen? - Armageddon  htt...       0
# ...                                                 ...     ...
# 6121               Slowly sinking wasting ?? @edsheeran       0
# 6122  The #Tribe just keeps sinking everyday it seem...       1
# 6123  that horrible sinking feeling when youÛªve be...       1
# 6124          each time we try we always end up sinking       0
# 6125  Do you feel like you are sinking in unhappines...       0
#
# [413 rows x 5 columns]

# %%
most_popular['keyword'].unique()
# Out:
# array(['armageddon', 'body%20bags', 'damage', 'deluge', 'evacuate',
#        'fatalities', 'fear', 'harm', 'outbreak', 'sinking'], dtype=object)

# %%
sns.set_theme()
sns.set(rc={"figure.figsize":(10, 5)})
sns.histplot(data=most_popular, x='keyword', hue='target')
# Out:
# <Axes: xlabel='keyword', ylabel='Count'>

# %% [markdown]
# **Выводы**: получается, фейковых новостей в целом больше, чем правдивых, кроме случаев о выспышках заболеваний (outbreak), а также эвакуациях (evacuate) и смертельных исходах (fatalities). Новости с ключевыми словами armageddon, body bags, harm, fear, deluge в большинстве своём фейковые.

# %% [markdown]
# ## Задание 3 (0.5 балла)
#
# В этом задании предлагается объединить все три текстовых столбца в один (просто сконкатенировать cтроки) и убрать столбец с индексом.

# %%
train.loc[[6590, 7122, 2769]]
# Out:
#          id          keyword      location  \
# 6590   9436        survivors  Marietta, GA
# 7122  10203  violent%20storm
# 2769   3980      devastation  Atlanta g.a.
#
#                                                    text  target
# 6590  Stemming from my #Cubs talk- the team rosters ...       1
# 7122  If you were the NWS wth a rotating storm w/ a ...       1
# 2769  http://t.co/Gxgm1T3W0J From Devastation to Ela...       0

# %%
train['text'] = train['keyword'] + train['location'] + train['text']
test['text'] = test['keyword'] + test['location'] + test['text']

train_new = train.drop(['id', 'keyword', 'location'], axis=1)
test_new = test.drop(['id', 'keyword', 'location'], axis=1)

# %%
train_new.loc[[6590, 7122, 2769]]
# Out:
#                                                    text  target
# 6590  survivorsMarietta, GAsurvivorsMarietta, GAsurv...       1
# 7122  violent%20stormviolent%20stormviolent%20stormI...       1
# 2769  devastationAtlanta g.a.devastationAtlanta g.a....       0

# %% [markdown]
# ## Задание 4 (0.5 балла)
#
# Далее мы будем пока работать только с train частью.
#
# 1. Предобработайте данные (train часть) с помощью CountVectorizer.
# 2. Какого размера получилась матрица?

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorize = CountVectorizer(analyzer='word', encoding='utf-8')
x_train = vectorize.fit_transform(train_new['text'].values)

# %%
vocab = vectorize.vocabulary_
vocab
# Out:
# {'bridge': 4091,
#  '20collapseashes': 504,
#  '2015': 297,
#  'australia': 2943,
#  'ûªs': 22707,
#  'collapse': 5237,
#  'at': 2820,
#  'trent': 20306,
#  'among': 2350,
#  'worst': 21971,
#  'in': 11061,
#  'history': 10473,
#  'england': 7870,
#  'bundled': 4222,
#  'out': 15090,
#  'for': 9084,
#  '60': 1403,
#  'http': 10695,
#  'co': 5182,
#  't5trhjuau0': 19380,
#  'hailcarol': 9993,
#  'stream': 18995,
#  'illinoisgreat': 10989,
#  'michigan': 13511,
#  'technique': 19526,
#  'camp': 4474,
#  'b1g': 3074,
#  'thanks': 19699,
#  'to': 20008,
#  'bmurph1019': 3851,
#  'hail_youtsey': 9986,
#  'termn8r13': 19586,
#  'goblue': 9674,
#  'wrestleon': 22109,
#  'oaskgki6qj': 14664,
#  'policehouston': 15805,
#  'cnn': 5175,
#  'tennessee': 19568,
#  'movie': 13876,
#  'theater': 19710,
#  'shooting': 18069,
#  'suspect': 19282,
#  'killed': 12076,
#  'by': 4323,
#  'police': 15800,
#  'di8elzswnr': 6877,
#  'riotingstill': 17117,
#  'rioting': 17099,
#  'couple': 5651,
#  'of': 14773,
#  'hours': 10651,
#  'left': 12510,
#  'until': 20834,
#  'have': 10159,
#  'be': 3318,
#  'up': 20845,
#  'class': 5096,
#  'woundslake': 22011,
#  'highlandscrack': 10377,
#  'the': 19707,
#  'path': 15408,
#  'where': 21664,
#  'wiped': 21836,
#  'this': 19794,
#  'morning': 13820,
#  'during': 7439,
#  'beach': 3321,
#  'run': 17404,
#  'surface': 19206,
#  'wounds': 21999,
#  'on': 14910,
#  'elbow': 7671,
#  'and': 2372,
#  'right': 17075,
#  'knee': 12152,
#  'yaqrsximph': 22337,
#  'airplane': 2150,
#  '20accidentsomewhere': 330,
#  'thereexperts': 19758,
#  'france': 9173,
#  'begin': 3379,
#  'examining': 8177,
#  'debris': 6308,
#  'found': 9133,
#  'reunion': 17002,
#  'island': 11450,
#  'french': 9224,
#  'air': 2143,
#  'accident': 1897,
#  'experts': 8230,
#  'tagzbcxfj0': 19402,
#  'mlb': 13702,
#  'bloodyisolated': 3801,
#  'city': 5050,
#  'world': 21939,
#  'perth': 15545,
#  'came': 4465,
#  'kill': 12075,
#  'indians': 11107,
#  'fun': 9299,
#  'video': 21206,
#  'smirking': 18422,
#  'remorseless': 16824,
#  'pakistani': 15248,
#  'killer': 12077,
#  'shows': 18100,
#  'him': 10448,
#  'boasting': 3864,
#  'fpjlwoxklg': 9154,
#  'burning': 4260,
#  'johnsontionne': 11754,
#  'except': 8182,
#  'idk': 10906,
#  'them': 19740,
#  'it': 11471,
#  'really': 16649,
#  'destroyhe': 6715,
#  'or': 15011,
#  'she': 18016,
#  'her': 10327,
#  'ask': 2786,
#  'destroy': 6692,
#  'house': 10652,
#  'woundedmaracay': 21986,
#  'nirgua': 14347,
#  'venezuelapolice': 21149,
#  'officer': 14790,
#  'wounded': 21980,
#  'dead': 6224,
#  'after': 2073,
#  'exchanging': 8186,
#  'shots': 18082,
#  'xxfk4khbiw': 22285,
#  'wreck': 22044,
#  'currently': 5946,
#  'writing': 22117,
#  'book': 3956,
#  'friggin': 9247,
#  'destiel': 6686,
#  'sucks': 19111,
#  'read': 16628,
#  'vine': 21228,
#  'description': 6631,
#  'https': 10696,
#  'mkx6ux4ozt': 13700,
#  'mudslidemalibu': 13945,
#  'santafe': 17567,
#  'winning': 21831,
#  'sterling': 18902,
#  'scott': 17684,
#  'red': 16699,
#  'carpet': 4612,
#  'fundraiser': 9302,
#  'oso': 15067,
#  'mudslide': 13933,
#  'ma4ra7atql': 13018,
#  'cg579wldne': 4839,
#  'casualtiescanadian': 4656,
#  'bread': 4060,
#  'libertarianluke': 12594,
#  'all': 2238,
#  'that': 19702,
#  'honest': 10553,
#  'if': 10916,
#  'people': 15508,
#  'want': 21419,
#  'go': 9666,
#  'rampage': 16533,
#  'let': 12560,
#  'use': 20981,
#  'their': 19735,
#  'own': 15166,
#  'hands': 10061,
#  'feet': 8660,
#  'no': 14404,
#  'casualties': 4651,
#  'ambulanceamsterdamhttp': 2309,
#  '7xglah10zl': 1570,
#  'twelve': 20502,
#  'feared': 8618,
#  'ambulance': 2308,
#  'helicopter': 10292,
#  'crash': 5701,
#  'thmblaatzp': 19801,
#  'electrocutedgot': 7688,
#  'electrocuted': 7686,
#  'last': 12392,
#  'night': 14332,
#  'work': 21929,
#  'first': 8806,
#  'time': 19933,
#  'my': 14023,
#  'life': 12606,
#  'shit': 18053,
#  'was': 21447,
#  'weird': 21605,
#  'drownsome': 7372,
#  'older': 14886,
#  'native': 14117,
#  'australians': 2954,
#  'believe': 3402,
#  'oceans': 14751,
#  'were': 21621,
#  'created': 5759,
#  'from': 9254,
#  'urine': 20909,
#  'an': 2360,
#  'angry': 2401,
#  'god': 9676,
#  'who': 21713,
#  'tried': 20324,
#  'drown': 7310,
#  'volcanowest': 21310,
#  'coast': 5191,
#  'cali': 4422,
#  'usathe': 20963,
#  'architect': 2598,
#  'behind': 3391,
#  'kanye': 11927,
#  'west': 21626,
#  'volcano': 21296,
#  'musbik7ejf': 13986,
#  'attackmumbaiindia': 2886,
#  'shud': 18107,
#  'not': 14469,
#  'give': 9599,
#  'any': 2484,
#  'evidence': 8163,
#  'pak': 15245,
#  'they': 19777,
#  'will': 21771,
#  'share': 18002,
#  'with': 21853,
#  'terrorists': 19632,
#  'amp': 2352,
#  'next': 14277,
#  'attack': 2848,
#  'oth': 15074,
#  'contries': 5560,
#  'qiopbtiuvu': 16291,
#  'body': 3872,
#  '20bagnew': 360,
#  'yorkauth': 22432,
#  'louis': 12867,
#  'vuitton': 21344,
#  'brown': 4143,
#  'saumur': 17599,
#  '35': 1135,
#  'cross': 5802,
#  'shoulder': 18084,
#  'bag': 3128,
#  'monogram': 13780,
#  '23': 1011,
#  '419': 1231,
#  'full': 9296,
#  'û_': 22690,
#  'hcdiwe5flc': 10218,
#  'zlvebeoavg': 22621,
#  'annihilatedhigher': 2429,
#  'placesthe': 15702,
#  'episode': 7973,
#  'trunks': 20396,
#  'annihilated': 2421,
#  'freiza': 9222,
#  'is': 11433,
#  'cleanest': 5103,
#  'ever': 8147,
#  'he': 10227,
#  'showed': 18096,
#  'nigga': 14330,
#  'mercy': 13432,
#  'cyclonehyderabad': 5990,
#  'roughdeal1': 17287,
#  'ante': 2466,
#  'hudhud': 10701,
#  'cyclone': 5981,
#  'chandrababu': 4869,
#  'valle': 21078,
#  'ne': 14183,
#  'ga': 9374,
#  'bloody65': 3793,
#  'zhenghxn': 22596,
#  '11': 118,
#  'eyes': 8334,
#  'akame': 2165,
#  'tokyo': 20032,
#  'ghoul': 9566,
#  'damn': 6094,
#  'bloody': 3792,
#  'dont': 7173,
#  'dare': 6151,
#  'watch': 21470,
#  'suicide': 19122,
#  '20bombingprincipality': 441,
#  'zeron': 22588,
#  'rayquazaerk': 16587,
#  'there': 19756,
#  'are': 2600,
#  'christian': 4998,
#  'sure': 19200,
#  'but': 4300,
#  'don': 7163,
#  'bombing': 3917,
#  'employed': 7818,
#  'often': 14811,
#  'as': 2760,
#  'islamic': 11446,
#  'groups': 9834,
#  'demolished': 6461,
#  'jackmulholland1': 11549,
#  'think': 19786,
#  'also': 2280,
#  'became': 3349,
#  'marquis': 13179,
#  'then': 19748,
#  'carlos': 4594,
#  'charlie': 4892,
#  'finally': 8746,
#  'dublin': 7404,
#  'sadly': 17481,
#  'inundatedlet': 11342,
#  'surf': 19204,
#  'hi': 10364,
#  'waimea': 21385,
#  'bay': 3275,
#  'like': 12648,
#  'inundated': 11332,
#  'surfers': 19207,
#  'czdw8oowa2': 6013,
#  'collisiondenver': 5350,
#  'coloradomotorcyclist': 5377,
#  'bicyclist': 3490,
#  'injured': 11173,
#  'denver': 6542,
#  'collision': 5344,
#  'broadway': 4125,
#  'zl7ojdaj3u': 22617,
#  'flamessomewhere': 8867,
#  'around': 2694,
#  'youmaryland': 22466,
#  'mansion': 13131,
#  'fire': 8768,
#  'caused': 4753,
#  'damaged': 6063,
#  'plug': 15755,
#  'under': 20766,
#  'christmas': 5004,
#  'tree': 20292,
#  'report': 16858,
#  'says': 17618,
#  'into': 11326,
#  'flames': 8847,
#  'lkjfabqzb3': 12739,
#  'demolishnyhcif': 6490,
#  'you': 22462,
#  'going': 9684,
#  'demolish': 6458,
#  'drake': 7228,
#  'over': 15139,
#  'some': 18544,
#  'ghostwriting': 9565,
#  'should': 18083,
#  'know': 12167,
#  'rihanna': 17079,
#  'lives': 12723,
#  'door': 7177,
#  'buildings': 4205,
#  '20burninggo': 491,
#  'blue': 3835,
#  'hail': 9985,
#  'yes': 22372,
#  '1acd4900c1424d1': 234,
#  'foxnews': 9146,
#  'one': 14915,
#  'down': 7198,
#  'looting': 12837,
#  'forest': 9099,
#  '20firesnicola': 680,
#  'valleyforest': 21080,
#  'fires': 8790,
#  'dying': 7474,
#  'salmon': 17515,
#  'act': 1954,
#  'deny': 6544,
#  'climate': 5125,
#  'change': 4870,
#  'nightmares': 14335,
#  'here': 10328,
#  'rbzomwgjee': 16608,
#  'bcpoli': 3308,
#  'canpoli': 4533,
#  'vanpoli': 21098,
#  'volcanohttp': 21304,
#  'ns1aggfnxz': 14521,
#  'shoes': 18064,
#  'asics': 2783,
#  'gt': 9857,
#  'ii': 10946,
#  'super': 19175,
#  'ronnie': 17254,
#  'fieg': 8712,
#  'kith': 12123,
#  'white': 21708,
#  '3m': 1187,
#  'gel': 9487,
#  'grey': 9810,
#  'od250zshfy': 14755,
#  'sandstormwatch': 17558,
#  'airport': 2152,
#  'get': 9536,
#  'swallowed': 19294,
#  'sandstorm': 17547,
#  'minute': 13631,
#  'wd9odwjj9l': 21511,
#  '20on': 752,
#  '20fireuk': 711,
#  'tweetlikeitsseptember11th2001': 20499,
#  'those': 19812,
#  'two': 20538,
#  'oil': 14848,
#  '20spillnew': 859,
#  'york': 22423,
#  'nycalifornia': 14591,
#  'spill': 18678,
#  'might': 13541,
#  'larger': 12385,
#  'than': 19693,
#  'projected': 16065,
#  'xwxbyhtuzc': 22284,
#  'wzedxefblg': 22175,
#  '20firescartoon': 657,
#  'bears': 3331,
#  'without': 21858,
#  'we': 21516,
#  'would': 21976,
#  'qave': 16263,
#  'knowlddge': 12169,
#  'toilet': 20029,
#  'paper': 15346,
#  'droughtmiami': 7299,
#  '_gaabyx': 1775,
#  'got': 9726,
#  'purple': 16200,
#  'activist': 1967,
#  'thought': 19815,
#  'drought': 7286,
#  'injuriesmadison': 11201,
#  'wi': 21727,
#  'st': 18771,
#  'mo': 13721,
#  'buffoonmike': 4199,
#  'knew': 12156,
#  'doing': 7145,
#  'much': 13930,
#  'bite': 3580,
#  'us': 20914,
#  'influenced': 11155,
#  'shitty': 18057,
#  'staff': 18780,
#  'injuries': 11191,
#  'acquisitions': 1949,
#  'landslideaustin': 12348,
#  'texas': 19650,
#  'toddstarnes': 20021,
#  'enjoy': 7914,
#  'impending': 11036,
#  'landslide': 12347,
#  'todd': 20019,
#  'hehe': 10278,
#  'apocalypseoregon': 2525,
#  'usago': 20934,
#  'look': 12823,
#  'grizzly': 9822,
#  'peak': 15480,
#  'now': 14499,
#  'looks': 12827,
#  'beginning': 3381,
#  'dystopian': 7478,
#  'apocalypse': 2514,
#  'detonationignition': 6791,
#  'knock': 12162,
#  'detonation': 6783,
#  'sensor': 17901,
#  'senso': 17900,
#  'standard': 18792,
#  'ks100': 12216,
#  '7o4lnfbe7k': 1562,
#  'fvzsgjtbew': 9330,
#  '20respondersthis': 818,
#  'week': 21596,
#  'responders': 16961,
#  'dart': 6162,
#  'members': 13410,
#  'participating': 15383,
#  'four': 9137,
#  'day': 6188,
#  'intensive': 11296,
#  'technical': 19524,
#  'large': 12384,
#  'animal': 2403,
#  'tl93aod3er': 19972,
#  'militarylot': 13572,
#  '20': 283,
#  'tom': 20037,
#  'clancy': 5092,
#  'military': 13562,
#  'mystery': 14039,
#  'novels': 14497,
#  'paperback': 15347,
#  'obix79ncxn': 14670,
#  'tomclancy': 20041,
#  'drowningcoventrywhy': 7345,
#  'drowning': 7340,
#  'low': 12883,
#  'self': 17873,
#  'image': 11011,
#  'take': 19410,
#  'quiz': 16400,
#  'z8r6r3nbtb': 22547,
#  'namffldh5h': 14087,
#  'apocalypsecoloradoi': 2520,
#  'gonna': 9695,
#  'fight': 8722,
#  'taylor': 19473,
#  'soon': 18575,
#  'dangerhailing': 6114,
#  'dayton': 6190,
#  'wish': 21848,
#  'could': 5636,
#  'victoria': 21197,
#  'secret': 17816,
#  'front': 9255,
#  'good': 9696,
#  'floodnew': 8971,
#  'yorkspot': 22452,
#  'flood': 8943,
#  'combo': 5398,
#  '53inch': 1337,
#  '300w': 1112,
#  'curved': 5950,
#  'cree': 5768,
#  'led': 12501,
#  'light': 12618,
#  'bar': 3187,
#  '4x4': 1310,
#  'offroad': 14804,
#  'fog': 9049,
#  'lamp': 12328,
#  're': 16616,
#  'o097vsotxk': 14635,
#  'i23xy7iejj': 10819,
#  'severe': 17951,
#  'weather': 21576,
#  'bulletin': 4210,
#  'typhoon': 20590,
#  'ûï': 22712,
#  'hannaph': 10069,
#  'soudelor': 18592,
#  'tropical': 20350,
#  'warning': 21435,
#  'issued': 11467,
#  '00': 0,
#  'pm': 15763,
#  '06': 24,
#  'thhjjw51pe': 19780,
#  'fits': 8815,
#  '01': 6,
#  'bmw': 3852,
#  '325ci': 1128,
#  '5l': 1374,
#  'l6': 12283,
#  'gbvdnczjou': 9474,
#  'c211hise0r': 4341,
#  'explosionlondon': 8293,
#  'united': 20804,
#  'kingdomaround': 12096,
#  '10': 89,
#  'explosion': 8280,
#  'chemical': 4922,
#  'park': 15368,
#  'western': 21627,
#  'germany': 9526,
#  'xbznu0qkvs': 22205,
#  'bombsoul': 3941,
#  'food': 9069,
#  'sound': 18597,
#  'so': 18500,
#  'bomb': 3882,
#  'terrorismtruth': 19614,
#  'bejftygjil': 3397,
#  'news': 14259,
#  'bbc': 3282,
#  'islam': 11443,
#  'truth': 20400,
#  'isis': 11441,
#  'terrorism': 19597,
#  'quran': 16408,
#  'lies': 12605,
#  'jlczidz7vu': 11719,
#  'sinkingmichigan': 18218,
#  'usa': 20918,
#  'your': 22472,
#  'lost': 12859,
#  'alone': 2268,
#  'sinking': 18206,
#  'stone': 18935,
#  'carry': 4616,
#  'onå': 14953,
#  'hostagenew': 10608,
#  'chicago': 4938,
#  'mylittlepwnies3': 14034,
#  'early__may': 7515,
#  'anathemazhiv': 2366,
#  'tonysandos': 20054,
#  'which': 21670,
#  'has': 10136,
#  'do': 7122,
#  'lebanon': 12497,
#  '80s': 1584,
#  'iran': 11406,
#  'hostage': 10602,
#  'crisis': 5791,
#  'libya': 12600,
#  'pan': 15263,
#  'am': 2295,
#  'policeus': 15820,
#  'pacalifornia': 15210,
#  'pulls': 16171,
#  'gun': 9887,
#  'man': 13109,
#  'apparent': 2545,
#  'provocation': 16121,
#  'lhw4vtbhzg': 12590,
#  'via': 21184,
#  'dailykos': 6041,
#  'derailmentminneapolis': 6607,
#  'mn': 13715,
#  'ustrain': 20996,
#  'derailment': 6596,
#  'patna': 15416,
#  'casualty': 4667,
#  'far': 8467,
#  'indian': 11101,
#  'express': 8310,
#  'yh5vetm0yz': 22385,
#  '17wgug8z0m': 196,
#  'panic': 15295,
#  'dream': 7243,
#  'magic': 13053,
#  'linden': 12671,
#  'method': 13461,
#  'lite': 12700,
#  'version': 21162,
#  'anxiety': 2483,
#  'cure': 5920,
#  'program': 16055,
#  '073izwx0lb': 29,
#  'lind': 12669,
#  'okmlagvkjv': 14875,
#  'rescuedjammu': 16891,
#  'kashmir': 11939,
#  'delhi18': 6394,
#  'bovines': 3999,
#  'rescued': 16881,
#  'smugglersåênabbed': 18452,
#  'e7fn5g5ruu': 7499,
#  'woundedfredericksburg': 21983,
#  'virginia': 21243,
#  'wwp': 22158,
#  'serving': 17934,
#  'more': 13811,
#  '75k': 1523,
#  'veterans': 21169,
#  '52k': 1333,
#  'oif': 14847,
#  'oef': 14767,
#  'vets': 21170,
#  'physical': 15613,
#  'many': 13135,
#  'invisible': 11374,
#  'ones': 14920,
#  'shhlv4dplz': 18033,
#  'client': 5121,
#  'dust': 7442,
#  '20stormi': 879,
#  'learned': 12488,
#  'about': 1865,
#  'economics': 7582,
#  'south': 18606,
#  'dakota': 6045,
#  'storm': 18949,
#  'did': 6893,
#  'years': 22356,
#  'college': 5292,
#  'hubert': 10700,
#  'humphrey': 10733,
#  'wrecked': 22070,
#  'cramer': 5694,
#  'iger': 10924,
#  'words': 21928,
#  'disney': 7012,
#  'stock': 18926,
#  'sf5jdnvdw9': 17963,
#  'til_now': 19927,
#  'cnbc': 5170,
#  'mudslidetring': 13953,
#  'marc_holl': 13143,
#  'nennicook': 14218,
#  'aitchkaycee': 2157,
#  'vixstuart': 21267,
#  'benjbeckwith': 3428,
#  'pretty': 15994,
#  'disaster': 6964,
#  'gbbo': 9466,
#  'obliterationcanada': 14717,
#  'need': 14199,
#  'arcade': 2595,
#  'shooter': 18068,
#  'fix': 8820,
#  'cte': 5885,
#  'empty': 7823,
#  'only': 14931,
#  'running': 17412,
#  'obliteration': 14713,
#  'even': 8141,
#  'buy': 4311,
#  'cod': 5208,
#  'title': 19960,
#  'weren': 21622,
#  'overpriced': 15147,
#  'steam': 18888,
#  'bioterrorismfirepower': 3544,
#  'lab': 12296,
#  'electronic': 7719,
#  'resource': 16953,
#  'automation': 2975,
#  'against': 2101,
#  'infectious': 11143,
#  'diseases': 7003,
#  'bioterrorism': 3538,
#  'kvpbybglsr': 12249,
#  'graysondolan': 9784,
#  'me': 13334,
#  'explodewashington': 8269,
#  'kendall': 11994,
#  'jenner': 11657,
#  'nick': 14302,
#  'jonas': 11766,
#  'dating': 6171,
#  'quite': 16399,
#  'literally': 12701,
#  'explode': 8237,
#  'pfvzvpxqgr': 15570,
#  'hostagei': 10605,
#  'always': 2294,
#  'tell': 19551,
#  'mom': 13764,
#  'bring': 4105,
#  'hold': 10510,
#  'cat': 4688,
#  'heat': 10264,
#  '20wavefort': 964,
#  'worth': 21974,
#  'rt': 17331,
#  'startelegram': 18818,
#  'homeless': 10539,
#  'vulnerable': 21347,
#  'north': 14448,
#  'wave': 21482,
#  'k9airfq3ql': 11899,
#  'jdbtlymehy': 11642,
#  'nuclear': 14536,
#  '20reactordenver': 780,
#  'conuclear': 5564,
#  'solar': 18526,
#  'power': 15899,
#  'japanese': 11599,
#  'fukushima': 9295,
#  'reactor': 16625,
#  'energy': 7859,
#  'japan': 11598,
#  'temperature': 19560,
#  'fuel': 9289,
#  'pool': 15835,
#  'ys3nmwwyvc': 22500,
#  'alpotnb7q3': 2273,
#  'collisionarvada': 5346,
#  'comotorcyclist': 5443,
#  'least': 12492,
#  'taken': 19413,
#  'local': 12769,
#  'wlmsq3mtho': 21878,
#  'traumanashville': 20253,
#  'tnesteemed': 19995,
#  'journalist': 11790,
#  'recalls': 16670,
#  'tragic': 20190,
#  'effects': 7629,
#  'unaddressed': 20750,
#  'childhood': 4948,
#  'trauma': 20239,
#  'keithboykin': 11985,
#  'randallpinkston': 16537,
#  'pozarmy': 15904,
#  'gxq1auzb18': 9930,
#  'panickingi': 15308,
#  'feel': 8652,
#  'panicking': 15303,
#  'results': 16984,
#  'back': 3105,
#  'alarmingly': 2194,
#  'calm': 4450,
#  'lightningthunder': 12637,
#  'lightning': 12624,
#  'possible': 15871,
#  'pinpoint': 15650,
#  'foothill': 9083,
#  'forecast': 9092,
#  'ctijdpxabk': 5887,
#  'displacednew': 7029,
#  'york40': 22429,
#  'displaced': 7023,
#  'ocean': 14750,
#  'township': 20140,
#  'apartment': 2504,
#  'newyork': 14272,
#  'uelz59wvom': 20681,
#  'massacrestay': 13218,
#  'tuned': 20460,
#  'freddiedeboer': 9200,
#  'thucydiplease': 19857,
#  'rise': 17141,
#  'coates': 5198,
#  'charleston': 4891,
#  'massacre': 13204,
#  'walter': 21412,
#  'black': 3603,
#  'twitter': 20537,
#  'broadly': 4124,
#  'well': 21610,
#  'deathstennessee': 6291,
#  'gallifrey': 9405,
#  'mathew_is_angry': 13240,
#  'z3ke_sk1': 22539,
#  'saladinahmed': 17505,
#  'died': 6899,
#  'horrible': 10589,
#  'deaths': 6278,
#  'trapped': 20217,
#  'ships': 18047,
#  'risk': 17144,
#  '20buildingswhiterun': 483,
#  'skyrimdestruction': 18345,
#  'fine': 8753,
#  'just': 11853,
#  'windstormpalm': 21812,
#  'county': 5648,
#  'flreality': 9023,
#  'training': 20196,
#  'train': 20194,
#  'falls': 8419,
#  'off': 14781,
#  'elevated': 7728,
#  'tracks': 20161,
#  'windstorm': 21794,
#  'jiomnrcygt': 11709,
#  'paramedic': 15356,
#  'ems': 7825,
#  'rescuers': 16908,
#  'fears': 8629,
#  'missing': 13659,
#  'migrants': 13544,
#  'med': 13348,
#  'search': 17796,
#  'survivors': 19264,
#  'boat': 3865,
#  'carrying': 4618,
#  '6ds67xai5e': 1454,
#  'derailedtorontoso': 6587,
#  'derailed_benchmark': 6568,
#  'cool': 5573,
#  'paths': 15412,
#  'wonder': 21910,
#  'can': 4488,
#  'find': 8750,
#  'leaks': 12485,
#  'jobs': 11737,
#  'given': 9602,
#  'resque': 16967,
#  'too': 20055,
#  'yorknew': 22446,
#  'ladies': 12306,
#  'tote': 20116,
#  'handbag': 10054,
#  'women': 21905,
#  'faux': 8575,
#  'leather': 12493,
#  'fashion': 8481,
#  'purse': 16205,
#  'y87gi3brlv': 22315,
#  '1zbhvdcxzs': 282,
#  'derailmentuk': 6612,
#  'raishimi33': 16523,
#  'sounds': 18601,
#  'plan': 15708,
#  'little': 12706,
#  'applaud': 2551,
#  'catastrophicbuxton': 4713,
#  'venice': 21150,
#  'nottingham': 14490,
#  'invading': 11364,
#  'iraq': 11411,
#  'catastrophic': 4711,
#  'mistake': 13669,
#  'diplomacy': 6937,
#  'needs': 14203,
#  'replace': 16853,
#  'constant': 5532,
#  'threat': 19823,
#  'war': 21424,
#  'israel': 11463,
#  'yqjpn3quux': 22490,
#  'hostagerelated': 10610,
#  'threatens': 19827,
#  'europe': 8058,
#  'wk6b5z803o': 21873,
#  'wreckedlivingston': 22081,
#  'mt': 13917,
#  'marynmck': 13192,
#  'beyond': 3464,
#  'adorable': 2010,
#  'hope': 10573,
#  'won': 21909,
#  'been': 3369,
#  'noticed': 14479,
#  'devastationmount': 6833,
#  'vernon': 21159,
#  'nydevastation': 14596,
#  'coming': 5410,
#  'target': 19445,
#  'starbucks': 18806,
#  'closed': 5139,
#  'momneedscoffee': 13768,
#  'asap': 2763,
#  'iwontmakeit': 11502,
#  'bombedscrewston': 3909,
#  'tx': 20544,
#  'redskins': 16713,
#  'wr': 22037,
#  'roberts': 17194,
#  'belly': 3409,
#  'bombed': 3890,
#  'teamstream': 19516,
#  'gbcvvevdty': 9467,
#  'hellfire': 10296,
#  'allah': 2239,
#  'describes': 6629,
#  'piling': 15641,
#  'wealth': 21522,
#  'thinking': 19787,
#  'forever': 9100,
#  'surah': 19199,
#  'humaza': 10725,
#  'reflect': 16727,
#  '20respondersworldwideloved': 822,
#  'way': 21489,
#  'written': 22120,
#  'include': 11074,
#  'vantage': 21099,
#  'points': 15791,
#  'detkenlang': 6762,
#  'kindle': 12088,
#  'kcrnmjkj73': 11968,
#  '20fires': 647,
#  'heartdisease': 10257,
#  'service': 17931,
#  'spending': 18669,
#  'half': 10035,
#  'budget': 4192,
#  'kzfigkeeva': 12268,
#  'tragedy': 20173,
#  'sandrablanddon': 17546,
#  'forget': 9104,
#  'gajtugaui7': 9397,
#  'mayhemdetroit': 13274,
#  'michigani': 13512,
#  'liked': 12649,
#  'youtube': 22480,
#  'itsjustinstuart': 11484,
#  'mnkaji2q1n': 13717,
#  'range': 16545,
#  'mayhem': 13269,
#  'devastation': 6821,
#  'hungerarticles': 10740,
#  'nepal': 14221,
#  'rebuilding': 16665,
#  'livelihoods': 12716,
#  'quake': 16326,
#  'lrouwjmbix': 12897,
#  'arsonistworldwidesuspected': 2727,
#  ...}

# %%
x_train.shape
# Out:
# (5329, 23874)

# %% [markdown]
# ## Задание 5 (1 балл)
#
# В предыдущем пункте у вас должна была получиться достаточно большая матрица.
# Если вы взгляните на текст, то увидете, что там есть множество специальных символов, ссылок и прочего мусора.
#
# Давайте также посмотрим на словарь, который получился в результате построения CountVectorizer, его можно найти в поле vocabulary_ инстанса этого класса. Давайте напишем функцию, которая печает ответы на следующие вопросы:
#
# 1. Найдите в этом словаре все слова, которые содержат цифры. Сколько таких слов нашлось?
#
# 2. Найдите все слова, которые содержат символы пунктуации. Сколько таких слов нашлось?
#
# 3. Сколько хэштегов (токен начинается на #) и упоминаний (токен начинается на @) осталось в словаре?

# %%
def contains_digit(s: str) -> bool:
    # Проверка, содержит ли слово цифры
    return bool(re.findall(r'\d+', s))

def contains_punctuation(s: str) -> bool:
    # Проверка, содержит ли слово пунктуацию
    return bool(re.findall(r'[^\w\s]+', s))

def is_hashtag(s: str) -> bool:
    # Проверка, является ли слово хэштегом
    return s[0] == '#'

def is_mention(s: str) -> bool:
    # Проверка, является ли слово упоминанием
    return s[0] == '@'

def investigate_vocabulary(vocabulary):
    digit_count = 0
    punct_count = 0
    hash_count = 0
    ment_count = 0
    for token in vocabulary:
        digit_count += 1 if contains_digit(token) else 0
        punct_count += 1 if contains_punctuation(token) else 0
        hash_count += 1 if is_hashtag(token) else 0
        ment_count += 1 if is_mention(token) else 0
    print('With digit:      ', digit_count
          )
    print('With punctuation:', punct_count
          )
    print('Hashtags:        ', hash_count
          )
    print('Mentions:        ', ment_count
          )

# %%
dummy_vocab = {'th1nk' : 0,
               'think333' : 1,
               'think.' : 2,
               'th!nk' : 3,
               'th...nk' : 4,
               '#think' : 5,
               '@think' : 6,
               '@thinking':7,
               '@nothink' : 8,
               'think' : 9}
investigate_vocabulary(dummy_vocab)
# Out:
# With digit:       2
# With punctuation: 7
# Hashtags:         1
# Mentions:         3

# %%
investigate_vocabulary(vocab)
# Out:
# With digit:       4590
# With punctuation: 0
# Hashtags:         0
# Mentions:         0

# %% [markdown]
# ## Задание 6 (0.5 балла)
#
# Вспомним, что на семинаре по текстам мы узнали, что в nltk есть специальный токенизатор для текстов - TweetTokenizer. Попробуем применить CountVectorizer с этим токенизатором. Ответьте на все вопросы из предыдущего пункта для TweetTokenizer и сравните результаты.

# %%
from nltk.tokenize import TweetTokenizer
# Чтобы узнать, какие параметры есть у этого токенайзера - используйте help(TweetTokenizer)
# Для того, чтобы передать токенайзер в CountVectorizer используйте параметр tokenizer

# %%
vectorize = CountVectorizer(tokenizer=TweetTokenizer().tokenize)
x_train = vectorize.fit_transform(train_new['text'])
token_vocab = vectorize.vocabulary_
token_vocab
# Out:
# C:\Users\vchemsmisl\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# {'bridge': 6424,
#  '%': 1476,
#  '20collapseashes': 1988,
#  '2015': 1779,
#  ':': 2899,
#  'australia': 5528,
#  '\x89': 23793,
#  'ûªs': 23843,
#  'collapse': 7361,
#  'at': 5427,
#  'trent': 22212,
#  'among': 5041,
#  'worst': 23461,
#  'in': 15248,
#  'history': 11636,
#  'england': 9558,
#  'bundled': 6531,
#  'out': 18018,
#  'for': 10613,
#  '60': 2744,
#  '...': 1515,
#  'http://t.co/t5trhjuau0': 14139,
#  'hailcarol': 11225,
#  'stream': 21126,
#  ',': 1487,
#  'illinoisgreat': 15192,
#  'michigan': 16922,
#  'technique': 21600,
#  'camp': 6729,
#  'b1g': 5630,
#  'thanks': 21750,
#  'to': 21961,
#  '@bmurph1019': 3161,
#  '@hail_youtsey': 3575,
#  '.': 1513,
#  '@termn8r13': 4387,
#  '#goblue': 521,
#  '#wrestleon': 1445,
#  'http://t.co/oaskgki6qj': 13685,
#  'policehouston': 18588,
#  'cnn': 7311,
#  'tennessee': 21636,
#  'movie': 17214,
#  'theater': 21756,
#  'shooting': 20342,
#  'suspect': 21399,
#  'killed': 15897,
#  'by': 6619,
#  'police': 18581,
#  'http://t.co/di8elzswnr': 12604,
#  'riotingstill': 19606,
#  'rioting': 19588,
#  'a': 4612,
#  'couple': 7751,
#  'of': 17793,
#  'hours': 11789,
#  'left': 16190,
#  'until': 22606,
#  'i': 15106,
#  'have': 11377,
#  'be': 5801,
#  'up': 22611,
#  'class': 7249,
#  'woundslake': 23500,
#  'highlandscrack': 11544,
#  'the': 21755,
#  'path': 18283,
#  'where': 23200,
#  'wiped': 23354,
#  'this': 21805,
#  'morning': 17164,
#  'during': 9253,
#  'beach': 5803,
#  'run': 19808,
#  'surface': 21327,
#  'wounds': 23488,
#  'on': 17887,
#  'elbow': 9386,
#  'and': 5056,
#  'right': 19567,
#  'knee': 15946,
#  'http://t.co/yaqrsximph': 14595,
#  'airplane': 4885,
#  '20accidentsomewhere': 1815,
#  'thereexperts': 21777,
#  'france': 10679,
#  'begin': 5849,
#  'examining': 9814,
#  'debris': 8273,
#  'found': 10659,
#  'reunion': 19515,
#  'island': 15588,
#  'french': 10718,
#  'air': 4878,
#  'accident': 4688,
#  'experts': 9862,
#  'http://t.co/tagzbcxfj0': 14147,
#  '#mlb': 792,
#  'bloodyisolated': 6198,
#  'city': 7212,
#  'world': 23431,
#  "perth'i": 18395,
#  'came': 6726,
#  'kill': 15896,
#  'indians': 15292,
#  'fun': 10777,
#  "'": 1478,
#  'video': 22865,
#  'smirking': 20643,
#  'remorseless': 19347,
#  'pakistani': 18136,
#  'killer': 15898,
#  'shows': 20374,
#  'him': 11613,
#  'boasting': 6240,
#  'http://t.co/fpjlwoxklg': 12818,
#  'burning': 6565,
#  '@johnsontionne': 3735,
#  'except': 9819,
#  'idk': 15147,
#  'them': 21763,
#  '?': 2923,
#  "it's": 15614,
#  'really': 19180,
#  'destroyhe': 8658,
#  '/': 1516,
#  'or': 17962,
#  'she': 20294,
#  'her': 11513,
#  '(': 1479,
#  'ask': 5400,
#  ')': 1483,
#  'destroy': 8635,
#  'house': 11790,
#  'woundedmaracay': 23475,
#  'y': 23643,
#  'nirgua': 17501,
#  'venezuelapolice': 22822,
#  'officer': 17806,
#  'wounded': 23469,
#  'dead': 8195,
#  'after': 4826,
#  'exchanging': 9823,
#  'shots': 20355,
#  'http://t.co/xxfk4khbiw': 14563,
#  'wreck': 23522,
#  'currently': 7998,
#  'writing': 23591,
#  'book': 6327,
#  "i'm": 15109,
#  'friggin': 10740,
#  'destiel': 8631,
#  'sucks': 21237,
#  'read': 19164,
#  'vine': 22882,
#  'description': 8578,
#  'https://t.co/mkx6ux4ozt': 14881,
#  'mudslidemalibu': 17246,
#  'santafe': 19926,
#  'winning': 23349,
#  '!': 0,
#  'sterling-scott': 21048,
#  'red': 19228,
#  'carpet': 6855,
#  'fundraiser': 10780,
#  'oso': 18004,
#  'mudslide': 17234,
#  'https://t.co/ma4ra7atql': 14877,
#  'http://t.co/cg579wldne': 12503,
#  'casualtiescanadian': 6894,
#  'bread': 6402,
#  '@libertarianluke': 3848,
#  'all': 4943,
#  'that': 21751,
#  'honest': 11696,
#  'if': 15150,
#  'people': 18361,
#  'want': 22995,
#  'go': 10998,
#  'rampage': 19095,
#  'let': 16229,
#  'use': 22731,
#  'their': 21761,
#  'own': 18089,
#  'hands': 11287,
#  'feet': 10235,
#  'no': 17527,
#  'casualties': 6889,
#  'ambulanceamsterdamhttp': 5003,
#  ':/': 2906,
#  't.co/7xglah10zl': 21470,
#  'twelve': 22362,
#  'feared': 10196,
#  'ambulance': 5001,
#  'helicopter': 11484,
#  'crash': 7789,
#  'http://t.co/thmblaatzp': 14178,
#  'electrocutedgot': 9402,
#  'electrocuted': 9398,
#  'last': 16103,
#  'night': 17490,
#  'work': 23421,
#  'first': 10365,
#  'time': 21916,
#  'my': 17303,
#  'life': 16255,
#  'shit': 20329,
#  'was': 23022,
#  'weird': 23161,
#  'drownsome': 9202,
#  'older': 17875,
#  'native': 17349,
#  'australians': 5538,
#  'believe': 5868,
#  'oceans': 17783,
#  'were': 23173,
#  'created': 7841,
#  'from': 10744,
#  'urine': 22665,
#  'an': 5048,
#  'angry': 5079,
#  'god': 11005,
#  'who': 23246,
#  'tried': 22225,
#  'drown': 9139,
#  'volcanowest': 22933,
#  'coast': 7323,
#  'cali': 6688,
#  'usathe': 22715,
#  'architect': 5235,
#  'behind': 5860,
#  'kanye': 15820,
#  'west': 23177,
#  'volcano': 22921,
#  'https://t.co/musbik7ejf': 14886,
#  'attackmumbaiindia': 5485,
#  'shud': 20379,
#  'not': 17581,
#  'give': 10960,
#  'any': 5147,
#  'evidence': 9804,
#  '2': 1754,
#  'pak.they': 18133,
#  'will': 23297,
#  'share': 20283,
#  'with': 23367,
#  'terrorists': 21697,
#  '&': 1477,
#  'next': 17456,
#  'attack.share': 5447,
#  'oth': 18007,
#  'contries': 7666,
#  'https://t.co/qiopbtiuvu': 14925,
#  'body': 6248,
#  '20bagnew': 1844,
#  'yorkauth': 23692,
#  'louis': 16462,
#  'vuitton': 22949,
#  'brown': 6469,
#  'saumur': 19950,
#  '35': 2586,
#  'cross': 7878,
#  'shoulder': 20358,
#  'bag': 5659,
#  'monogram': 17130,
#  '7.23': 2784,
#  '419-3': 2648,
#  '-': 1488,
#  'full': 10773,
#  'û_': 23827,
#  'http://t.co/hcdiwe5flc': 12990,
#  'http://t.co/zlvebeoavg': 14707,
#  'annihilatedhigher': 5099,
#  'placesthe': 18504,
#  'episode': 9647,
#  'trunks': 22283,
#  'annihilated': 5092,
#  'freiza': 10716,
#  'is': 15578,
#  'cleanest': 7254,
#  'ever': 9787,
#  'he': 11424,
#  'showed': 20370,
#  'nigga': 17488,
#  'mercy': 16870,
#  'cyclonehyderabad': 8025,
#  '@roughdeal1': 4213,
#  'ante': 5131,
#  'hudhud': 15028,
#  'cyclone': 8017,
#  'chandrababu': 7065,
#  'valle': 22778,
#  'ne': 17389,
#  'ga': 10805,
#  'bloody': 6188,
#  '65': 2764,
#  '@zhenghxn': 4601,
#  '11': 1616,
#  'eyes': 9958,
#  'akame': 4895,
#  'tokyo': 21978,
#  'ghoul': 10940,
#  'damn': 8104,
#  'dont': 9030,
#  'dare': 8143,
#  'watch': 23043,
#  'suicide': 21248,
#  '20bombingprincipality': 1925,
#  'zeron': 23767,
#  '@rayquazaerk': 4167,
#  'there': 21774,
#  'are': 5237,
#  'christian': 7176,
#  'sure': 21322,
#  'but': 6605,
#  "don't": 9021,
#  'bombing': 6292,
#  'employed': 9514,
#  'often': 17823,
#  'as': 5382,
#  'it': 15612,
#  'islamic': 15586,
#  'groups': 11131,
#  'demolished': 8414,
#  '@jackmulholland1': 3686,
#  'think': 21797,
#  'also': 4979,
#  'became': 5826,
#  'marquis': 16659,
#  'then': 21768,
#  'carlos': 6839,
#  "charlie's": 7089,
#  'finally': 10308,
#  "dublin's": 9223,
#  'sadly': 19857,
#  'inundatedlet': 15508,
#  'surf': 21326,
#  'hi': 11529,
#  'waimea': 22963,
#  'bay': 5781,
#  'like': 16294,
#  'inundated': 15498,
#  'surfers': 21328,
#  'https://t.co/czdw8oowa2': 14806,
#  'collisiondenver': 7471,
#  'coloradomotorcyclist': 7498,
#  'bicyclist': 5929,
#  'injured': 15347,
#  'denver': 8490,
#  'collision': 7464,
#  'broadway': 6454,
#  'http://t.co/zl7ojdaj3u': 14703,
#  'flamessomewhere': 10415,
#  'around': 5324,
#  'youmaryland': 23729,
#  'mansion': 16624,
#  'fire': 10329,
#  '6': 2739,
#  'caused': 6984,
#  'damaged': 8075,
#  'plug': 18554,
#  'under': 22546,
#  'christmas': 7179,
#  'tree': 22201,
#  'report': 19376,
#  'says': 19962,
#  'into': 15492,
#  'flames': 10395,
#  'http://t.co/lkjfabqzb3': 13410,
#  'demolishnyhcif': 8443,
#  'you': 23722,
#  'going': 11012,
#  'demolish': 8411,
#  "drake's": 9070,
#  'over': 18067,
#  'some': 20750,
#  'ghostwriting': 10939,
#  'should': 20356,
#  'know': 15959,
#  'rihanna': 19570,
#  'lives': 16357,
#  'door': 9032,
#  'buildings': 6515,
#  '20burninggo': 1975,
#  'blue': 6227,
#  'hail': 11219,
#  'yes': 23672,
#  '@1acd4900c1424d1': 2929,
#  '@foxnews': 3505,
#  'one': 17891,
#  'down': 9049,
#  'looting': 16440,
#  'forest': 10627,
#  '20firesnicola': 2163,
#  'valleyforest': 22780,
#  'fires': 10350,
#  'dying': 9265,
#  'salmon': 19881,
#  'act': 4737,
#  'deny': 8492,
#  'climate': 7274,
#  'change': 7066,
#  'nightmares': 17492,
#  'here': 11514,
#  'http://t.co/rbzomwgjee': 13972,
#  '#bcpoli': 156,
#  '#canpoli': 231,
#  '#vanpoli': 1371,
#  'volcanohttp': 22927,
#  't.co/ns1aggfnxz': 21495,
#  '#shoes': 1145,
#  'asics': 5398,
#  'gt-ii': 11144,
#  'super': 21298,
#  '2.0': 1756,
#  'ronnie': 19695,
#  'fieg': 10278,
#  'kith': 15940,
#  'white': 23242,
#  '3m': 2616,
#  'x': 23613,
#  'gel': 10890,
#  'grey': 11110,
#  'http://t.co/od250zshfy': 13693,
#  'sandstormwatch': 19918,
#  'airport': 4888,
#  'get': 10926,
#  'swallowed': 21409,
#  'sandstorm': 19907,
#  'minute': 17033,
#  'http://t.co/wd9odwjj9l': 14433,
#  '20on': 2235,
#  '20fireuk': 2194,
#  '#tweetlikeitsseptember11th2001': 1339,
#  'those': 21811,
#  'two': 22396,
#  'oil': 17847,
#  '20spillnew': 2341,
#  'york': 23688,
#  'nycalifornia': 17666,
#  'spill': 20867,
#  'might': 16952,
#  'larger': 16097,
#  'than': 21744,
#  'projected': 18812,
#  'http://t.co/xwxbyhtuzc': 14562,
#  'http://t.co/wzedxefblg': 14492,
#  '20firescartoon': 2140,
#  'bears': 5811,
#  'without': 23372,
#  'we': 23071,
#  'would': 23463,
#  'qave': 18945,
#  'knowlddge': 15961,
#  'toilet': 21976,
#  'paper': 18229,
#  'droughtmiami': 9129,
#  '@_gaabyx': 2957,
#  'got': 11045,
#  'purple': 18922,
#  'activist': 4749,
#  'thought': 21814,
#  'drought': 9116,
#  'injuriesmadison': 15375,
#  'wi': 23258,
#  'st': 20934,
#  'mo': 17088,
#  '@buffoonmike': 3190,
#  'knew': 15948,
#  'doing': 9003,
#  'much': 17232,
#  'bite': 6006,
#  'us': 22668,
#  'influenced': 15333,
#  'shitty': 20333,
#  'staff': 20940,
#  'injuries': 15365,
#  'acquisitions': 4732,
#  'landslideaustin': 16063,
#  'texas': 21713,
#  '@toddstarnes': 4446,
#  'enjoy': 9604,
#  'impending': 15228,
#  'landslide': 16060,
#  'todd': 21969,
#  'hehe': 11473,
#  'apocalypseoregon': 5176,
#  'usago': 22688,
#  'look': 16426,
#  'grizzly': 11120,
#  'peak': 18334,
#  'now': 17608,
#  'looks': 16430,
#  'beginning': 5851,
#  'dystopian': 9267,
#  'apocalypse': 5165,
#  'detonationignition': 8734,
#  'knock': 15954,
#  'detonation': 8726,
#  'sensor-senso': 20198,
#  'standard': 20952,
#  'ks100': 15987,
#  'http://t.co/7o4lnfbe7k': 12168,
#  'http://t.co/fvzsgjtbew': 12841,
#  '20respondersthis': 2301,
#  'week': 23151,
#  'responders': 19476,
#  'dart': 8149,
#  'members': 16851,
#  'participating': 18259,
#  'four': 10663,
#  'day': 8166,
#  'intensive': 15463,
#  'technical': 21598,
#  'large': 16096,
#  'animal': 5080,
#  'http://t.co/tl93aod3er': 14190,
#  'militarylot': 16975,
#  '20': 1765,
#  'tom': 21983,
#  'clancy': 7245,
#  'military': 16968,
#  'mystery': 17309,
#  'novels': 17606,
#  'paperback': 18230,
#  'http://t.co/obix79ncxn': 13688,
#  '#tomclancy': 1290,
#  'drowningcoventrywhy': 9175,
#  'drowning': 9170,
#  'low': 16473,
#  'self-image': 20172,
#  'take': 21530,
#  'quiz': 19018,
#  'http://t.co/z8r6r3nbtb': 14671,
#  'http://t.co/namffldh5h': 13579,
#  "apocalypsecoloradoi'm": 5171,
#  'gonna': 11021,
#  'fight': 10287,
#  'taylor': 21575,
#  'soon': 20779,
#  'dangerhailing': 8121,
#  'dayton': 8170,
#  'wish': 23363,
#  'could': 7737,
#  "victoria's": 22858,
#  'secret': 20118,
#  'front': 10745,
#  'good': 11022,
#  'floodnew': 10513,
#  'yorkspot': 23712,
#  'flood': 10485,
#  'combo': 7516,
#  '53inch': 2712,
#  '300w': 2560,
#  'curved': 8002,
#  'cree': 7849,
#  'led': 16185,
#  'light': 16266,
#  'bar': 5703,
#  '4x4': 2686,
#  'offroad': 17818,
#  'fog': 10581,
#  'lamp': 16043,
#  're': 19151,
#  'http://t.co/o097vsotxk': 13661,
#  'http://t.co/i23xy7iejj': 13064,
#  'severe': 20243,
#  'weather': 23133,
#  'bulletin': 6520,
#  '5': 2688,
#  'typhoon': 22439,
#  'ûï': 23848,
#  '#hannaph': 556,
#  'û': 23826,
#  '\x9d': 23795,
#  'soudelor': 20792,
#  'tropical': 22247,
#  'warning': 23010,
#  'issued': 15608,
#  '5:00': 2728,
#  'pm': 18561,
#  '06': 1544,
#  'http://t.co/thhjjw51pe': 14177,
#  'fits': 10373,
#  '01-06': 1529,
#  'bmw': 6234,
#  '325ci': 2578,
#  '2.5': 1761,
#  'l-l': 16013,
#  'http://t.co/gbvdnczjou': 12881,
#  'http://t.co/c211hise0r': 12470,
#  'explosionlondon': 9924,
#  'united': 22581,
#  'kingdomaround': 15917,
#  '10': 1582,
#  'explosion': 9910,
#  'chemical': 7112,
#  'park': 18245,
#  'western': 23179,
#  'germany': 10918,
#  'http://t.co/xbznu0qkvs': 14509,
#  'bombsoul': 6315,
#  'food': 10599,
#  'sound': 20798,
#  'so': 20711,
#  'bomb': 6257,
#  'terrorismtruth': 21679,
#  'https://t.co/bejftygjil': 14795,
#  '#news': 848,
#  '#bbc': 151,
#  '#cnn': 275,
#  '#islam': 650,
#  '#truth': 1325,
#  '#god': 522,
#  '#isis': 649,
#  '#terrorism': 1251,
#  '#quran': 1030,
#  '#lies': 727,
#  'http://t.co/jlczidz7vu': 13208,
#  'sinkingmichigan': 20483,
#  'usa': 22671,
#  '¢': 23797,
#  'your': 23733,
#  'lost': 16455,
#  'alone': 4969,
#  'sinking': 20470,
#  'stone': 21075,
#  'carry': 6859,
#  'onå': 17920,
#  '¡': 23796,
#  'å': 23809,
#  'hostagenew': 11746,
#  'chicago': 7124,
#  '@mylittlepwnies3': 4009,
#  '@early__may': 3433,
#  '@anathemazhiv': 3030,
#  '@tonysandos': 4457,
#  'which': 23206,
#  'has': 11354,
#  'do': 8984,
#  'lebanon': 16183,
#  '80s': 2833,
#  'attack': 5446,
#  'iran': 15557,
#  'hostage': 11740,
#  'crisis': 7869,
#  'libya': 16249,
#  'pan': 18149,
#  'am': 4991,
#  'policeus': 18603,
#  'pacalifornia': 18098,
#  'pulls': 18897,
#  'gun': 11170,
#  'man': 16604,
#  'apparent': 5194,
#  'provocation': 18864,
#  'http://t.co/lhw4vtbhzg': 13403,
#  'via': 22845,
#  '@dailykos': 3328,
#  'derailmentminneapolis': 8554,
#  'mn': 17085,
#  'ustrain': 22738,
#  'derailment': 8543,
#  'patna': 18291,
#  'news': 17450,
#  'casualty': 6905,
#  'far': 10067,
#  'indian': 15287,
#  'express': 9941,
#  'http://t.co/yh5vetm0yz': 14613,
#  'http://t.co/17wgug8z0m': 11868,
#  'panic': 18181,
#  '#dream': 363,
#  '#magic': 759,
#  '#linden': 730,
#  'method': 16890,
#  'lite': 16338,
#  'version': 22834,
#  '#': 1,
#  '1': 1567,
#  'anxiety': 5146,
#  'cure': 7973,
#  'program': 18805,
#  'http://t.co/073izwx0lb': 11815,
#  'lind': 16311,
#  'http://t.co/okmlagvkjv': 13715,
#  'rescuedjammu': 19409,
#  '|': 23788,
#  'kashmir': 15827,
#  'delhi': 8351,
#  '18': 1706,
#  'bovines': 6363,
#  'rescued': 19399,
#  '3': 2546,
#  'smugglersåênabbed': 20670,
#  'http://t.co/e7fn5g5ruu': 12676,
#  'woundedfredericksburg': 23472,
#  'virginia': 22894,
#  '@wwp': 4565,
#  'serving': 20229,
#  'more': 17159,
#  '75k': 2805,
#  'veterans': 22842,
#  '52k': 2708,
#  'oif': 17846,
#  'oef': 17791,
#  'vets': 22843,
#  'physical': 18438,
#  ';': 2911,
#  'many': 16628,
#  'invisible': 15538,
#  'ones': 17895,
#  'http://t.co/shhlv4dplz': 14073,
#  '#client': 272,
#  'dust': 9255,
#  '20stormi': 2361,
#  'learned': 16175,
#  'about': 4663,
#  'economics': 9334,
#  'south': 20806,
#  'dakota': 8060,
#  'storm': 21085,
#  'did': 8809,
#  'years': 23661,
#  'college': 7415,
#  'hubert': 15027,
#  'humphrey': 15051,
#  'wrecked': 23546,
#  'cramer': 7783,
#  "iger's": 15155,
#  'words': 23420,
#  "disney's": 8917,
#  'stock': 21066,
#  'http://t.co/sf5jdnvdw9': 14068,
#  '#til_now': 1283,
#  '#cnbc': 274,
#  'mudslidetring': 17254,
#  '@marc_holl': 3904,
#  '@nennicook': 4027,
#  '@aitchkaycee': 3001,
#  '@vixstuart': 4516,
#  '@benjbeckwith': 3128,
#  'pretty': 18753,
#  '#disaster': 346,
#  '#gbbo': 499,
#  '#mudslide': 813,
#  'obliterationcanada': 17753,
#  'need': 17404,
#  'arcade': 5233,
#  'shooter': 20341,
#  'fix': 10378,
#  'cte': 7952,
#  'empty': 9518,
#  'only': 17903,
#  'running': 19814,
#  'obliteration': 17751,
#  "i'd": 15107,
#  'even': 9782,
#  'buy': 6615,
#  'cod': 7338,
#  'title': 21938,
#  'they': 21785,
#  "weren't": 23175,
#  'overpriced': 18076,
#  'steam': 21036,
#  'bioterrorismfirepower': 5975,
#  'lab': 16018,
#  '[': 4602,
#  'electronic': 9435,
#  'resource': 19468,
#  ']': 4606,
#  'automation': 5557,
#  'against': 4843,
#  'infectious': 15324,
#  'diseases': 8907,
#  'bioterrorism': 5970,
#  'http://t.co/kvpbybglsr': 13342,
#  '@graysondolan': 3560,
#  'u': 22474,
#  'me': 16785,
#  'explodewashington': 9900,
#  'd.c.kendall': 8045,
#  'jenner': 15701,
#  'nick': 17467,
#  'jonas': 15755,
#  'dating': 8157,
#  'quite': 19017,
#  'literally': 16339,
#  'explode': 9868,
#  'http://t.co/pfvzvpxqgr': 13793,
#  'hostagei': 11743,
#  'always': 4990,
#  'tell': 21620,
#  'mom': 17115,
#  'bring': 6436,
#  'hold': 11660,
#  'cat': 6926,
#  'heat': 11461,
#  '20wavefort': 2446,
#  'worth': 23462,
#  'rt': 19745,
#  '@startelegram': 4325,
#  'homeless': 11684,
#  'vulnerable': 22952,
#  'north': 17565,
#  'wave': 23053,
#  'http://t.co/k9airfq3ql': 13268,
#  'http://t.co/jdbtlymehy': 13188,
#  'nuclear': 17624,
#  '20reactordenver': 2263,
#  'conuclear': 7670,
#  '#solar': 1177,
#  'power': 18678,
#  '#japanese': 664,
#  '#fukushima': 481,
#  'reactor': 19160,
#  'energy': 9550,
#  'japan': 15670,
#  'temperature': 21628,
#  'fuel': 10767,
#  'pool': 18617,
#  'http://t.co/ys3nmwwyvc': 14645,
#  'http://t.co/alpotnb7q3': 12321,
#  'collisionarvada': 7467,
#  'comotorcyclist': 7555,
#  'least': 16178,
#  'taken': 21533,
#  'local': 16385,
#  'http://t.co/wlmsq3mtho': 14455,
#  'traumanashville': 22164,
#  'tnesteemed': 21952,
#  'journalist': 15769,
#  'recalls': 19198,
#  'tragic': 22107,
#  'effects': 9364,
#  'unaddressed': 22530,
#  '#childhood': 260,
#  '#trauma': 1305,
#  '@keithboykin': 3782,
#  '@randallpinkston': 4158,
#  '@pozarmy': 4125,
#  'http://t.co/gxq1auzb18': 12954,
#  'panickingi': 18194,
#  'feel': 10229,
#  'panicking': 18189,
#  'results': 19498,
#  'back': 5642,
#  'alarmingly': 4913,
#  'calm': 6716,
#  'lightningthunder': 16285,
#  'lightning': 16272,
#  'possible': 18648,
#  'pinpoint': 18472,
#  'foothill': 10612,
#  'forecast': 10620,
#  'http://t.co/ctijdpxabk': 12542,
#  'displacednew': 8932,
#  '40': 2631,
#  'displaced': 8927,
#  'ocean': 17782,
#  'township': 22068,
#  'apartment': 5159,
#  '#newyork': 854,
#  'http://t.co/uelz59wvom': 14271,
#  'massacrestay': 16694,
#  'tuned': 22334,
#  ';)': 2912,
#  '@freddiedeboer': 3511,
#  '@thucydiplease': 4428,
#  'rise': 19630,
#  'coates': 7330,
#  'charleston': 7087,
#  'massacre': 16681,
#  'walter': 22988,
#  'scott': 20010,
#  'black': 6015,
#  'twitter': 22395,
#  'broadly': 6453,
#  'well': 23166,
#  'deathstennessee': 8257,
#  'gallifrey': 10832,
#  '@mathew_is_angry': 3919,
#  '@z3ke_sk1': 4592,
#  '@saladinahmed': 4232,
#  'died': 8815,
#  'horrible': 11728,
#  'deaths': 8244,
#  'trapped': 22130,
#  'ships': 20324,
#  'risk': 19633,
#  '20buildingswhiterun': 1967,
#  'skyrimdestruction': 20583,
#  "magic's": 16556,
#  'fine': 10315,
#  'just': 15802,
#  'windstormpalm': 23332,
#  'county': 7749,
#  'flreality': 10563,
#  'training': 22113,
#  'train': 22111,
#  'falls': 10024,
#  'off': 17796,
#  'elevated': 9441,
#  'tracks': 22081,
#  'windstorm': 23314,
#  'http://t.co/jiomnrcygt': 13202,
#  '#paramedic': 952,
#  '#ems': 397,
#  'rescuers': 19426,
#  '#world': 1437,
#  'fears': 10207,
#  'missing': 17056,
#  'migrants': 16955,
#  'med': 16802,
#  'search': 20102,
#  'survivors': 21383,
#  'boat': 6241,
#  'carrying': 6861,
#  'http://t.co/6ds67xai5e': 12101,
#  'derailedtorontoso': 8534,
#  'derailed_benchmark': 8515,
#  'cool': 7679,
#  'paths': 18287,
#  'wonder': 23404,
#  'can': 6743,
#  'find': 10312,
#  'leaks': 16173,
#  'jobs': 15739,
#  'given': 10962,
#  'resque': 19482,
#  'too': 21994,
#  'yorknew': 23706,
#  'ladies': 16026,
#  'tote': 22046,
#  'handbag': 11281,
#  'women': 23397,
#  'faux': 10169,
#  'leather': 16179,
#  'fashion': 10079,
#  'purse': 18926,
#  'http://t.co/y87gi3brlv': 14589,
#  'http://t.co/1zbhvdcxzs': 11910,
#  'derailmentuk': 8559,
#  '@raishimi33': 4157,
#  ':)': 2902,
#  'sounds': 20801,
#  'plan': 18510,
#  'little': 16343,
#  'applaud': 5200,
#  'catastrophicbuxton': 6950,
#  'venice': 22823,
#  "nottingham'invading": 17600,
#  'iraq': 15560,
#  'catastrophic': 6948,
#  'mistake': 17063,
#  'diplomacy': 8845,
#  'needs': 17408,
#  'replace': 19371,
#  'constant': 7639,
#  'threat': 21821,
#  'war': 23000,
#  'israel': 15603,
#  'http://t.co/yqjpn3quux': 14640,
#  'hostagerelated': 11748,
#  'isis': 15581,
#  'threatens': 21824,
#  'europe': 9701,
#  'http://t.co/wk6b5z803o': 14452,
#  'wreckedlivingston': 23557,
#  'mt': 17230,
#  '@marynmck': 3917,
#  "that's": 21753,
#  'beyond': 5916,
#  'adorable': 4780,
#  'hope': 11714,
#  "won't": 23403,
#  'been': 5841,
#  'noticed': 17590,
#  'devastationmount': 8773,
#  'vernon': 22832,
#  'nydevastation': 17670,
#  'coming': 7526,
#  '@target': 4370,
#  '@starbucks': 4324,
#  'closed': 7283,
#  '#momneedscoffee': 797,
#  '#asap': 113,
#  '#iwontmakeit': 658,
#  'bombedscrewston': 6284,
#  "tx'redskins": 22403,
#  'wr': 23516,
#  'roberts': 19658,
#  'belly-bombed': 5875,
#  '@teamstream': 4380,
#  'http://t.co/gbcvvevdty': 12876,
#  'hellfire': 11488,
#  '#allah': 69,
#  'describes': 8576,
#  'piling': 18463,
#  '#wealth': 1405,
#  ...}

# %%
investigate_vocabulary(token_vocab)
# Out:
# With digit:       4609
# With punctuation: 7544
# Hashtags:         1474
# Mentions:         1678

# %% [markdown]
# **Сравнение:** Получается, дефолтное преобразование текстовых значений в векторы игнорирует знаки препинания, что устраняется внедрением токенизатора. Также можно заметить, что незначительно отличается число токенов с числами, выделенных обоими векторизаторами.

# %% [markdown]
# ## Задание 7 (2 балла)
#
# В scikit-learn мы можем оценивать процесс подсчета матрицы через CountVectorizer. У CountVectorizer, как и у других наследников \_VectorizerMixin, есть аргумент tokenizer и preprocessor. preprocessor применится в самом начале к каждой строке вашего датасета, tokenizer же должен принять строку и вернуть токены.
# Давайте напишем кастомный токенайзер, которые сделает все, что нам нужно:
#
# 0. Приведет все буквы к нижнему регистру
# 1. Разобьет текст на токены с помощью TweetTokenizer из пакета nltk
# 2. Удалит все токены содержащие не латинские буквы, кроме смайликов (будем считать ими токены содержащие только пунктуацию и, как минимум, одну скобочку) и хэштегов, которые после начальной # содержат только латинские буквы.
# 3. Удалит все токены, которые перечислены в nltk.corpus.stopwords.words('english')
# 4. Проведет стемминг с помощью SnowballStemmer

# %%
tokenizer = TweetTokenizer()

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vchemsmisl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def contains_only_latin_letters(s: str) -> bool:
    # Проверка, содержит ли слово только латинские буквы
    return bool(re.fullmatch(r'[a-z]+', s))

def is_emoji(s: str) -> bool:
    # Проверка, является ли слово смайликом
    return bool(re.fullmatch(r'[^\w\s]+\s?[^\w\s]?\s?[)()]+', s))

def is_hashtag(s: str) -> bool:
    # Проверка, является ли слово хэштегом
    return s[0] == '#'

def custom_tokenizer(s: str) -> List[str]:    
    # Кастомный токенайзер
    s = s.lower()
    tokens = tokenizer.tokenize(s)
    clean_tokens = []
    for token in tokens:
        if token in nltk.corpus.stopwords.words('english'):
            continue
        if contains_only_latin_letters(token) or \
        is_emoji(token) or is_hashtag(token):
            stem_token = stemmer.stem(token)
            clean_tokens.append(stem_token)
    return clean_tokens

# %%
custom_tokenizer('She LOVES painting :-) #art')
# Out:
# ['love', 'paint', ':-)', '#art']

# %% [markdown]
# Продемонстрируйте работу вашей функции на первых десяти текстах в обучающей выборке.

# %%
train['text'][:10].map(custom_tokenizer)
# Out:
# 1186    [bridg, australia, collaps, trent, bridg, amon...
# 4071    [hailcarol, stream, illinoisgreat, michigan, t...
# 5461    [policehouston, cnn, tennesse, movi, theater, ...
# 5787        [riotingstil, riot, coupl, hour, left, class]
# 7445    [woundslak, highlandscrack, path, wipe, morn, ...
# 151     [airplan, thereexpert, franc, begin, examin, a...
# 915     [bloodyisol, citi, world, came, kill, indian, ...
# 1305                    [burn, except, idk, realli, burn]
# 2570                       [destroyh, ask, destroy, hous]
# 7399    [woundedmaracay, nirgua, venezuelapolic, offic...
# Name: text, dtype: object

# %% [markdown]
# ## Задание 8 (1 балл)
#
# 1. Примените CountVectorizer с реализованным выше токенизатором к обучающим и тестовым выборкам.

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer)
train_vec = vectorizer.fit_transform(train_new['text']).toarray()
test_vec = vectorizer.transform(test_new['text']).toarray()
# Out:
# C:\Users\vchemsmisl\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
train_vec.shape, test_vec.shape
# Out:
# ((5329, 13970), (2284, 13970))

# %% [markdown]
# 2. Обучите LogisticRegression на полученных признаках.

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(train_vec, train_new['target'])
predict = logreg.predict(test_vec)

# %% [markdown]
# 3. Посчитайте метрику f1-score на тестовых данных.

# %%
from sklearn.metrics import f1_score
f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# 'F1 score: 0.7422907488986784'

# %% [markdown]
# ## Задание 9 (1 балл)
#
# 1. Повторите 8 задание, но с tf-idf векторизатором. Как изменилось качество?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 1
vectorizer = TfidfVectorizer(tokenizer=custom_tokenizer)
train_vec = vectorizer.fit_transform(train_new['text']).toarray()
test_vec = vectorizer.transform(test_new['text']).toarray()

logreg = LogisticRegression()
logreg.fit(train_vec, train_new['target'])
predict = logreg.predict(test_vec)

f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# C:\Users\vchemsmisl\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 'F1 score: 0.7319294251565169'

# %% [markdown]
# 1. **Ответ:** F1 score немного упал, т.е. качество модели ухудшилось

# %% [markdown]
# 2. Мы можем еще сильнее уменьшить размер нашей матрицы, если отбросим значения df близкие к единице. Скорее всего такие слова не несут много информации о категории, так как встречаются достаточно часто. Ограничьте максимальный df в параметрах TfIdfVectorizer, поставьте верхнюю границу равную 0.9. Как изменился размер матрицы, как изменилось качество?

# %%
# 2
vectorizer = TfidfVectorizer(tokenizer=custom_tokenizer, max_df=0.9)
train_vec1 = vectorizer.fit_transform(train_new['text']).toarray()
test_vec1 = vectorizer.transform(test_new['text']).toarray()

logreg = LogisticRegression()
logreg.fit(train_vec1, train_new['target'])
predict = logreg.predict(test_vec1)

f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# 'F1 score: 0.7319294251565169'

# %%
train_vec1.shape, test_vec1.shape
# Out:
# ((5329, 13970), (2284, 13970))

# %% [markdown]
# 2. **Ответ:** Качество модели не изменилось, размер тоже не поменялся

# %% [markdown]
# 3. Также мы можем уменьшить размер матрицы, удаляя слова со слишком маленьким df. Удалось ли добиться улучшения качества?

# %%
# 3
vectorizer = TfidfVectorizer(tokenizer=custom_tokenizer, max_df=0.9, min_df=0.0005)
train_vec = vectorizer.fit_transform(train_new['text']).toarray()
test_vec = vectorizer.transform(test_new['text']).toarray()

logreg = LogisticRegression()
logreg.fit(train_vec, train_new['target'])
predict = logreg.predict(test_vec)

f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# C:\Users\vchemsmisl\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 'F1 score: 0.7325056433408578'

# %%
train_vec.shape, test_vec.shape
# Out:
# ((5329, 2930), (2284, 2930))

# %% [markdown]
# 3. **Ответ:** Качество почти не меняется

# %% [markdown]
# ## Задание 10 (1 балл)
#
# Еще один популяпный трюк, который позволит уменьшить количество признаков называется hashing trick. Его суть в том, то мы случайно группируем признаки ииии  ..... складываем их! А потом удаляем исходные признаки. В итоге все наши признаки это просто суммы исходных. Звучит странно, но это отлично работает. Давайте проверим этот трюк в нашем сеттинге.
# Также при таком подходе вам не нужно хранить словарь token->index, что тоже иногда полезно.
#
# 1. Повторите задание 8 с HashingVectorizer, укажите количество фичей равное 5000.

# %%
from sklearn.feature_extraction.text import HashingVectorizer

vectorizer = HashingVectorizer(tokenizer=custom_tokenizer, n_features=5000)
train_vec = vectorizer.fit_transform(train_new['text']).toarray()
test_vec = vectorizer.transform(test_new['text']).toarray()

logreg = LogisticRegression()
logreg.fit(train_vec, train_new['target'])
predict = logreg.predict(test_vec)

f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# C:\Users\vchemsmisl\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 'F1 score: 0.709494030699261'

# %% [markdown]
# 2. Какой из подходов показал самый высокий результат?

# %% [markdown]
# 2. **Ответ:** Подход с CountVectorizer

# %% [markdown]
# ## Задание 11 (1 балл)
#
# В этом задании нужно добиться f1 меры хотя в 0.75 на тестовых данных.

# %%
vectorizer = CountVectorizer()
train_vec = vectorizer.fit_transform(train_new['text']).toarray()
test_vec = vectorizer.transform(test_new['text']).toarray()

logreg = LogisticRegression()
logreg.fit(train_vec, train_new['target'])
predict = logreg.predict(test_vec)

f'F1 score: {f1_score(test["target"], predict)}'
# Out:
# 'F1 score: 0.7506819421713039'

# %% [markdown]
# *Кажется, лучший результат получается при векторизации целого текста без токенизации*

# %%
train_vec.shape, test_vec.shape
# Out:
# ((5329, 3593), (2284, 3593))

# %%
import numpy as np
arr = np.array([[50, 50, 50], [6, 7, 8]])
arr[:len(arr), :-1]
# Out:
# array([[50, 50],
#        [ 6,  7]])
